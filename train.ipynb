# %%
import os
import numpy as np
import pandas as pd
import json
import joblib
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy import interpolate

# %%
# 1. 数据加载函数
def load_all_data(base_path):
    """
    加载所有CSV文件并处理为训练格式
    """
    all_samples = []
    all_labels = []
    
    for action_id in range(6):  # 0-5.csv
        file_path = os.path.join(base_path, f"{action_id}.csv")
        try:
            df = pd.read_csv(file_path)
            
            # 验证数据格式
            required_columns = ['acc_x', 'acc_y', 'acc_z', 'gyr_x', 'gyr_y', 'gyr_z', 'sample', 'label']
            if not all(col in df.columns for col in required_columns):
                print(f"文件 {file_path} 缺少必要的列，跳过")
                continue
            
            # 按样本分组
            for sample_id in df['sample'].unique():
                sample_data = df[df['sample'] == sample_id]
                
                # 确保每个样本有100个数据点
                if len(sample_data) < 100:
                    # 插值补全到100点
                    new_index = np.linspace(0, 1, 100)
                    old_index = np.linspace(0, 1, len(sample_data))
                    
                    interpolated = pd.DataFrame()
                    for col in ['acc_x', 'acc_y', 'acc_z', 'gyr_x', 'gyr_y', 'gyr_z']:
                        f = interpolate.interp1d(old_index, sample_data[col], kind='cubic')
                        interpolated[col] = f(new_index)
                    
                    sample_data = interpolated
                elif len(sample_data) > 100:
                    sample_data = sample_data.head(100)
                
                # 提取传感器数据
                sensor_data = sample_data[['acc_x', 'acc_y', 'acc_z', 'gyr_x', 'gyr_y', 'gyr_z']].values
                all_samples.append(sensor_data)
                all_labels.append(action_id)
                
        except Exception as e:
            print(f"加载文件 {file_path} 时出错: {e}")
    
    return np.array(all_samples), np.array(all_labels)

# %%
# 2. 数据预处理
def preprocess_data(X, y):
    """
    数据预处理：标准化和分割
    """
    # 划分训练集和测试集
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.2, stratify=y, random_state=42
    )
    
    # 标准化数据
    train_2d = X_train.reshape(-1, X_train.shape[-1])
    scaler = StandardScaler()
    scaler.fit(train_2d)
    
    # 应用相同的标准化到所有数据
    def scale_dataset(dataset):
        original_shape = dataset.shape
        flat = dataset.reshape(-1, dataset.shape[-1])
        scaled = scaler.transform(flat)
        return scaled.reshape(original_shape)
    
    X_train_scaled = scale_dataset(X_train)
    X_test_scaled = scale_dataset(X_test)
    
    # One-hot编码标签
    num_classes = len(np.unique(y))  # 获取实际类别数
    y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=num_classes)
    y_test_cat = tf.keras.utils.to_categorical(y_test, num_classes=num_classes)
    
    return X_train_scaled, X_test_scaled, y_train_cat, y_test_cat, scaler, num_classes

# %%
# 3. 模型构建
def create_model(input_shape, num_classes):
    """
    创建CNN-LSTM模型
    """
    model = models.Sequential([
        layers.Input(shape=input_shape),
        
        # 1D CNN 特征提取
        layers.Conv1D(32, kernel_size=5, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.3),
        
        layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.4),
        
        # LSTM 时序建模
        layers.LSTM(64, return_sequences=True),
        layers.Dropout(0.5),
        layers.LSTM(32),
        layers.Dropout(0.5),
        
        # 分类层
        layers.Dense(32, activation='relu'),
        layers.Dense(num_classes, activation='softmax')
    ])
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    model.summary()
    return model

# %%
# 4. 保存训练结果
def save_training_results(model, scaler, history, test_acc, label_names, num_classes):
    """
    保存模型、标准化器和训练元数据
    """
    # 创建保存目录
    save_dir = "saved_model"
    os.makedirs(save_dir, exist_ok=True)
    
    # 保存模型
    model.save(os.path.join(save_dir, "gesture_model.h5"))
    
    # 保存标准化器
    joblib.dump(scaler, os.path.join(save_dir, "scaler.pkl"))
    
    # 保存标签映射
    label_mapping = {i: name for i, name in enumerate(label_names)}
    with open(os.path.join(save_dir, "label_mapping.json"), 'w') as f:
        json.dump(label_mapping, f, indent=2)
    
    # 保存训练历史
    history_df = pd.DataFrame(history.history)
    history_df.to_csv(os.path.join(save_dir, "training_history.csv"), index=False)
    
    # 保存元数据
    metadata = {
        "test_accuracy": float(test_acc),
        "input_shape": model.input_shape[1:],
        "num_classes": num_classes,
        "created_at": pd.Timestamp.now().isoformat()
    }
    with open(os.path.join(save_dir, "metadata.json"), 'w') as f:
        json.dump(metadata, f, indent=2)
    
    print(f"所有训练结果已保存到 {save_dir} 目录")

# %%
# 主训练函数
def train_gesture_model(data_path, label_names):
    """
    完整训练流程
    """
    print("=== 开始训练手势识别模型 ===")
    
    # 1. 加载数据
    print("加载数据...")
    X, y = load_all_data(data_path)
    print(f"加载完成: {len(X)} 个样本")
    
    # 2. 预处理
    print("预处理数据...")
    X_train, X_test, y_train, y_test, scaler, num_classes = preprocess_data(X, y)
    print(f"训练集: {X_train.shape[0]} 样本, 测试集: {X_test.shape[0]} 样本, 类别数: {num_classes}")
    
    # 3. 构建模型
    print("构建模型...")
    model = create_model((100, 6), num_classes)
    
    # 4. 训练模型
    print("训练模型...")
    early_stopping = callbacks.EarlyStopping(
        monitor='val_loss', patience=20, restore_best_weights=True
    )
    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6
    )
    model_checkpoint = callbacks.ModelCheckpoint(
        'best_model.h5', save_best_only=True, monitor='val_accuracy'
    )
    
    history = model.fit(
        X_train, y_train,
        epochs=200,
        batch_size=16,
        validation_data=(X_test, y_test),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )
    
    # 5. 评估模型
    print("评估模型...")
    model.load_weights('best_model.h5')  # 加载最佳模型
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"测试准确率: {test_acc:.4f}")
    
    # 6. 保存结果
    print("保存训练结果...")
    save_training_results(model, scaler, history, test_acc, label_names, num_classes)
    
    print("=== 训练完成 ===")

# %%
if __name__ == "__main__":
    # 配置参数
    DATA_PATH = "sample"  # 包含0.csv到5.csv的目录
    LABEL_NAMES = ["up", "down", "left", "right", "circle_clock", "circle_anticlock"]
    
    # 开始训练
    train_gesture_model(DATA_PATH, LABEL_NAMES)
# Out:
# === 开始训练手势识别模型 ===
# 加载数据...
# 加载完成: 60 个样本
# 预处理数据...
# 训练集: 48 样本, 测试集: 12 样本, 类别数: 6
# 构建模型...
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 100, 32)        │           992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 100, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 50, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 50, 64)         │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 50, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 25, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 25, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 25, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 25, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,278 (212.02 KB)
#  Trainable params: 54,086 (211.27 KB)
#  Non-trainable params: 192 (768.00 B)
# 训练模型...
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2882 - loss: 1.7940
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 433ms/step - accuracy: 0.2839 - loss: 1.7913 - val_accuracy: 0.2500 - val_loss: 1.7746 - learning_rate: 0.0010
# Epoch 2/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.3125 - loss: 1.7074
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2995 - loss: 1.7114 - val_accuracy: 0.4167 - val_loss: 1.7542 - learning_rate: 0.0010
# Epoch 3/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4375 - loss: 1.6540
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4271 - loss: 1.6548 - val_accuracy: 0.7500 - val_loss: 1.7351 - learning_rate: 0.0010
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3594 - loss: 1.6495 - val_accuracy: 0.7500 - val_loss: 1.7138 - learning_rate: 0.0010
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4427 - loss: 1.6084 - val_accuracy: 0.7500 - val_loss: 1.6864 - learning_rate: 0.0010
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6042 - loss: 1.5051 - val_accuracy: 0.6667 - val_loss: 1.6520 - learning_rate: 0.0010
# Epoch 7/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6250 - loss: 1.4797
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5859 - loss: 1.4895 - val_accuracy: 0.8333 - val_loss: 1.6084 - learning_rate: 0.0010
# Epoch 8/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7500 - loss: 1.4322
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6458 - loss: 1.4337 - val_accuracy: 0.9167 - val_loss: 1.5529 - learning_rate: 0.0010
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5755 - loss: 1.3943 - val_accuracy: 0.9167 - val_loss: 1.4899 - learning_rate: 0.0010
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6953 - loss: 1.2856 - val_accuracy: 0.9167 - val_loss: 1.4170 - learning_rate: 0.0010
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7734 - loss: 1.2153 - val_accuracy: 0.9167 - val_loss: 1.3313 - learning_rate: 0.0010
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7266 - loss: 1.1733 - val_accuracy: 0.9167 - val_loss: 1.2469 - learning_rate: 0.0010
# Epoch 13/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8750 - loss: 1.1593
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8750 - loss: 1.0847 - val_accuracy: 1.0000 - val_loss: 1.1688 - learning_rate: 0.0010
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7708 - loss: 1.0144 - val_accuracy: 1.0000 - val_loss: 1.0911 - learning_rate: 0.0010
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8880 - loss: 0.8999 - val_accuracy: 1.0000 - val_loss: 1.0115 - learning_rate: 0.0010
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.7772 - val_accuracy: 1.0000 - val_loss: 0.9250 - learning_rate: 0.0010
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9349 - loss: 0.7021 - val_accuracy: 1.0000 - val_loss: 0.8333 - learning_rate: 0.0010
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9323 - loss: 0.6378 - val_accuracy: 1.0000 - val_loss: 0.7515 - learning_rate: 0.0010
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9635 - loss: 0.5938 - val_accuracy: 1.0000 - val_loss: 0.6720 - learning_rate: 0.0010
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9661 - loss: 0.5047 - val_accuracy: 1.0000 - val_loss: 0.5976 - learning_rate: 0.0010
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9479 - loss: 0.4498 - val_accuracy: 1.0000 - val_loss: 0.5280 - learning_rate: 0.0010
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.3874 - val_accuracy: 1.0000 - val_loss: 0.4587 - learning_rate: 0.0010
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9479 - loss: 0.3002 - val_accuracy: 1.0000 - val_loss: 0.3975 - learning_rate: 0.0010
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2782 - val_accuracy: 1.0000 - val_loss: 0.3448 - learning_rate: 0.0010
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9896 - loss: 0.2526 - val_accuracy: 1.0000 - val_loss: 0.2989 - learning_rate: 0.0010
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9661 - loss: 0.2792 - val_accuracy: 1.0000 - val_loss: 0.2601 - learning_rate: 0.0010
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2625 - val_accuracy: 1.0000 - val_loss: 0.2252 - learning_rate: 0.0010
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.2196 - val_accuracy: 1.0000 - val_loss: 0.1948 - learning_rate: 0.0010
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.1531 - val_accuracy: 1.0000 - val_loss: 0.1673 - learning_rate: 0.0010
# Epoch 30/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.1499 - val_accuracy: 1.0000 - val_loss: 0.1434 - learning_rate: 0.0010
# Epoch 31/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.1285 - val_accuracy: 1.0000 - val_loss: 0.1241 - learning_rate: 0.0010
# Epoch 32/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1092 - val_accuracy: 1.0000 - val_loss: 0.1065 - learning_rate: 0.0010
# Epoch 33/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.1046 - val_accuracy: 1.0000 - val_loss: 0.0922 - learning_rate: 0.0010
# Epoch 34/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.1125 - val_accuracy: 1.0000 - val_loss: 0.0816 - learning_rate: 0.0010
# Epoch 35/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0889 - val_accuracy: 1.0000 - val_loss: 0.0714 - learning_rate: 0.0010
# Epoch 36/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9714 - loss: 0.0846 - val_accuracy: 1.0000 - val_loss: 0.0623 - learning_rate: 0.0010
# Epoch 37/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0888 - val_accuracy: 1.0000 - val_loss: 0.0542 - learning_rate: 0.0010
# Epoch 38/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0593 - val_accuracy: 1.0000 - val_loss: 0.0479 - learning_rate: 0.0010
# Epoch 39/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0716 - val_accuracy: 1.0000 - val_loss: 0.0429 - learning_rate: 0.0010
# Epoch 40/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.1431 - val_accuracy: 1.0000 - val_loss: 0.0382 - learning_rate: 0.0010
# Epoch 41/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 1.0000 - val_loss: 0.0340 - learning_rate: 0.0010
# Epoch 42/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0647 - val_accuracy: 1.0000 - val_loss: 0.0305 - learning_rate: 0.0010
# Epoch 43/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0404 - val_accuracy: 1.0000 - val_loss: 0.0274 - learning_rate: 0.0010
# Epoch 44/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9818 - loss: 0.0853 - val_accuracy: 1.0000 - val_loss: 0.0245 - learning_rate: 0.0010
# Epoch 45/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0711 - val_accuracy: 1.0000 - val_loss: 0.0218 - learning_rate: 0.0010
# Epoch 46/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0482 - val_accuracy: 1.0000 - val_loss: 0.0197 - learning_rate: 0.0010
# Epoch 47/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0351 - val_accuracy: 1.0000 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 48/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0680 - val_accuracy: 1.0000 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 49/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0360 - val_accuracy: 1.0000 - val_loss: 0.0148 - learning_rate: 0.0010
# Epoch 50/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 1.0000 - val_loss: 0.0136 - learning_rate: 0.0010
# Epoch 51/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0403 - val_accuracy: 1.0000 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 52/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9818 - loss: 0.0512 - val_accuracy: 1.0000 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 53/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0676 - val_accuracy: 1.0000 - val_loss: 0.0109 - learning_rate: 0.0010
# Epoch 54/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0231 - val_accuracy: 1.0000 - val_loss: 0.0103 - learning_rate: 0.0010
# Epoch 55/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0263 - val_accuracy: 1.0000 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 56/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0371 - val_accuracy: 1.0000 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 57/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0472 - val_accuracy: 1.0000 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 58/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 59/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0300 - val_accuracy: 1.0000 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 60/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0410 - val_accuracy: 1.0000 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 61/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 0.0067 - learning_rate: 0.0010
# Epoch 62/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0346 - val_accuracy: 1.0000 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 63/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0256 - val_accuracy: 1.0000 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 64/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0378 - val_accuracy: 1.0000 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 65/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 66/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 67/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 68/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 69/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 70/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0367 - val_accuracy: 1.0000 - val_loss: 0.0044 - learning_rate: 0.0010
# Epoch 71/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0369 - val_accuracy: 1.0000 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 72/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 1.0000 - val_loss: 0.0039 - learning_rate: 0.0010
# Epoch 73/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 74/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 1.0000 - val_loss: 0.0035 - learning_rate: 0.0010
# Epoch 75/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 76/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 77/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 78/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 79/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 80/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 1.0000 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 81/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 82/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0025 - learning_rate: 0.0010
# Epoch 83/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 84/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 85/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 86/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 87/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0329 - val_accuracy: 1.0000 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 88/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 0.0020 - learning_rate: 0.0010
# Epoch 89/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 1.0000 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 90/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 91/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 92/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 93/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 94/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 95/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 96/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 97/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 98/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 99/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0014 - learning_rate: 0.0010
# Epoch 100/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 101/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 102/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 103/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 104/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 105/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0123 - val_accuracy: 1.0000 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 106/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 107/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 108/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 109/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 9.8783e-04 - learning_rate: 0.0010
# Epoch 110/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 9.5920e-04 - learning_rate: 0.0010
# Epoch 111/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 9.3137e-04 - learning_rate: 0.0010
# Epoch 112/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 9.0568e-04 - learning_rate: 0.0010
# Epoch 113/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 8.7963e-04 - learning_rate: 0.0010
# Epoch 114/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 8.5849e-04 - learning_rate: 0.0010
# Epoch 115/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 8.3698e-04 - learning_rate: 0.0010
# Epoch 116/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 8.1603e-04 - learning_rate: 0.0010
# Epoch 117/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 7.9823e-04 - learning_rate: 0.0010
# Epoch 118/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 7.8171e-04 - learning_rate: 0.0010
# Epoch 119/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 7.6239e-04 - learning_rate: 0.0010
# Epoch 120/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 7.6075e-04 - learning_rate: 5.0000e-04
# Epoch 121/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 7.6466e-04 - learning_rate: 5.0000e-04
# Epoch 122/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 7.6764e-04 - learning_rate: 5.0000e-04
# Epoch 123/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 7.6936e-04 - learning_rate: 5.0000e-04
# Epoch 124/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0172 - val_accuracy: 1.0000 - val_loss: 7.6899e-04 - learning_rate: 5.0000e-04
# Epoch 125/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 7.6710e-04 - learning_rate: 2.5000e-04
# Epoch 126/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0208 - val_accuracy: 1.0000 - val_loss: 7.6392e-04 - learning_rate: 2.5000e-04
# Epoch 127/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 7.5943e-04 - learning_rate: 2.5000e-04
# Epoch 128/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 7.5377e-04 - learning_rate: 2.5000e-04
# Epoch 129/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 7.4858e-04 - learning_rate: 2.5000e-04
# Epoch 130/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 7.4378e-04 - learning_rate: 2.5000e-04
# Epoch 131/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 7.3894e-04 - learning_rate: 2.5000e-04
# Epoch 132/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 7.3407e-04 - learning_rate: 2.5000e-04
# Epoch 133/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 7.2907e-04 - learning_rate: 2.5000e-04
# Epoch 134/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 7.2603e-04 - learning_rate: 1.2500e-04
# Epoch 135/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 1.0000 - val_loss: 7.2303e-04 - learning_rate: 1.2500e-04
# Epoch 136/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 7.1994e-04 - learning_rate: 1.2500e-04
# Epoch 137/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 7.1697e-04 - learning_rate: 1.2500e-04
# Epoch 138/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 7.1381e-04 - learning_rate: 1.2500e-04
# Epoch 139/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 7.1194e-04 - learning_rate: 6.2500e-05
# Epoch 140/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 7.1007e-04 - learning_rate: 6.2500e-05
# Epoch 141/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 7.0822e-04 - learning_rate: 6.2500e-05
# Epoch 142/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 7.0617e-04 - learning_rate: 6.2500e-05
# Epoch 143/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 7.0402e-04 - learning_rate: 6.2500e-05
# Epoch 144/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9661 - loss: 0.0586 - val_accuracy: 1.0000 - val_loss: 7.0240e-04 - learning_rate: 3.1250e-05
# Epoch 145/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 7.0065e-04 - learning_rate: 3.1250e-05
# Epoch 146/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 1.0000 - val_loss: 6.9895e-04 - learning_rate: 3.1250e-05
# Epoch 147/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 6.9741e-04 - learning_rate: 3.1250e-05
# Epoch 148/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 6.9604e-04 - learning_rate: 3.1250e-05
# Epoch 149/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 6.9511e-04 - learning_rate: 1.5625e-05
# Epoch 150/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 6.9436e-04 - learning_rate: 1.5625e-05
# Epoch 151/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 1.0000 - val_loss: 6.9347e-04 - learning_rate: 1.5625e-05
# Epoch 152/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 6.9254e-04 - learning_rate: 1.5625e-05
# Epoch 153/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 6.9179e-04 - learning_rate: 1.5625e-05
# Epoch 154/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 6.9117e-04 - learning_rate: 7.8125e-06
# Epoch 155/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 6.9050e-04 - learning_rate: 7.8125e-06
# Epoch 156/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 6.8978e-04 - learning_rate: 7.8125e-06
# Epoch 157/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 6.8910e-04 - learning_rate: 7.8125e-06
# Epoch 158/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 6.8836e-04 - learning_rate: 7.8125e-06
# Epoch 159/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 6.8784e-04 - learning_rate: 3.9063e-06
# Epoch 160/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 6.8721e-04 - learning_rate: 3.9063e-06
# Epoch 161/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 6.8675e-04 - learning_rate: 3.9063e-06
# Epoch 162/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 6.8624e-04 - learning_rate: 3.9063e-06
# Epoch 163/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 6.8577e-04 - learning_rate: 3.9063e-06
# Epoch 164/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 1.0000 - val_loss: 6.8527e-04 - learning_rate: 1.9531e-06
# Epoch 165/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 6.8479e-04 - learning_rate: 1.9531e-06
# Epoch 166/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 6.8447e-04 - learning_rate: 1.9531e-06
# Epoch 167/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 6.8400e-04 - learning_rate: 1.9531e-06
# Epoch 168/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 6.8365e-04 - learning_rate: 1.9531e-06
# Epoch 169/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 6.8334e-04 - learning_rate: 1.0000e-06
# Epoch 170/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 6.8298e-04 - learning_rate: 1.0000e-06
# Epoch 171/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 6.8279e-04 - learning_rate: 1.0000e-06
# Epoch 172/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 6.8244e-04 - learning_rate: 1.0000e-06
# Epoch 173/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 6.8204e-04 - learning_rate: 1.0000e-06
# Epoch 174/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 6.8179e-04 - learning_rate: 1.0000e-06
# Epoch 175/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 6.8162e-04 - learning_rate: 1.0000e-06
# Epoch 176/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 6.8124e-04 - learning_rate: 1.0000e-06
# Epoch 177/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 6.8090e-04 - learning_rate: 1.0000e-06
# Epoch 178/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 6.8070e-04 - learning_rate: 1.0000e-06
# Epoch 179/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 6.8037e-04 - learning_rate: 1.0000e-06
# Epoch 180/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 6.8011e-04 - learning_rate: 1.0000e-06
# Epoch 181/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 6.7976e-04 - learning_rate: 1.0000e-06
# Epoch 182/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 6.7954e-04 - learning_rate: 1.0000e-06
# Epoch 183/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 6.7928e-04 - learning_rate: 1.0000e-06
# Epoch 184/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 1.0000 - val_loss: 6.7912e-04 - learning_rate: 1.0000e-06
# Epoch 185/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 6.7901e-04 - learning_rate: 1.0000e-06
# Epoch 186/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 6.7877e-04 - learning_rate: 1.0000e-06
# Epoch 187/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 6.7852e-04 - learning_rate: 1.0000e-06
# Epoch 188/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 6.7826e-04 - learning_rate: 1.0000e-06
# Epoch 189/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 6.7806e-04 - learning_rate: 1.0000e-06
# Epoch 190/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 6.7791e-04 - learning_rate: 1.0000e-06
# Epoch 191/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 6.7767e-04 - learning_rate: 1.0000e-06
# Epoch 192/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 6.7749e-04 - learning_rate: 1.0000e-06
# Epoch 193/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 1.0000 - val_loss: 6.7729e-04 - learning_rate: 1.0000e-06
# Epoch 194/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 6.7706e-04 - learning_rate: 1.0000e-06
# Epoch 195/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 6.7679e-04 - learning_rate: 1.0000e-06
# Epoch 196/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 6.7652e-04 - learning_rate: 1.0000e-06
# Epoch 197/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 6.7636e-04 - learning_rate: 1.0000e-06
# Epoch 198/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 6.7615e-04 - learning_rate: 1.0000e-06
# Epoch 199/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 6.7604e-04 - learning_rate: 1.0000e-06
# Epoch 200/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 6.7596e-04 - learning_rate: 1.0000e-06
# 评估模型...
# 测试准确率: 1.0000
# 保存训练结果...
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 所有训练结果已保存到 saved_model 目录
# === 训练完成 ===
